# %% [markdown]
# # Download [national test statistics](https://www.skolverket.se/skolutveckling/statistik/sok-statistik-om-forskola-skola-och-vuxenutbildning?sok=SokD&niva=S&omr=natprov&uttag=null&filter=1&lan=01&hmtyp=a&exp=12&lasar=2019)
#
# ![alt text](download.png "Title")

# %%
import pandas as pd

years = [2019, 2018, 2017]
grade = 3
subjects = ['Math', 'Swedish', 'Swedish_as_a_second_language']

df_dict = {}
for i, s in enumerate(subjects):
    for year in years:
        title = f'{year}_grade-{grade}_{s}'
        df_dict[title] = pd.read_excel(f'data/exp_ap{grade}_{year}.xlsx',
                                   sheet_name=i, 
                                   header=7
                                  )

# %%
df_dict.keys()
# Out:
# dict_keys(['2019_grade-3_Math', '2018_grade-3_Math', '2017_grade-3_Math', '2019_grade-3_Swedish', '2018_grade-3_Swedish', '2017_grade-3_Swedish', '2019_grade-3_Swedish_as_a_second_language', '2018_grade-3_Swedish_as_a_second_language', '2017_grade-3_Swedish_as_a_second_language'])

# %%
keys = list(df_dict.keys())

df_dict[keys[0]]
# Out:
#                  Skola  Skol-enhetskod Skolkommun  Kommun-kod Typ av huvudman  \
# 0      Banslättsskolan        86192571   Botkyrka         127        Kommunal
# 1      Banslättsskolan        86192571   Botkyrka         127        Kommunal
# 2      Banslättsskolan        86192571   Botkyrka         127        Kommunal
# 3      Banslättsskolan        86192571   Botkyrka         127        Kommunal
# 4      Banslättsskolan        86192571   Botkyrka         127        Kommunal
# ...                ...             ...        ...         ...             ...
# 5404  Österskärsskolan        94113162  Österåker         117        Kommunal
# 5405  Österskärsskolan        94113162  Österåker         117        Kommunal
# 5406  Österskärsskolan        94113162  Österåker         117        Kommunal
# 5407  Österskärsskolan        94113162  Österåker         117        Kommunal
# 5408  Österskärsskolan        94113162  Österåker         117        Kommunal
#
#        Huvudman  Huvudman orgnr                                     Delprov  \
# 0      Botkyrka      2120002882                       Muntlig kommunikation
# 1      Botkyrka      2120002882   Tals inbördes relation, positionssystemet
# 2      Botkyrka      2120002882                    Förståelse för räknesätt
# 3      Botkyrka      2120002882                                  Tid, volym
# 4      Botkyrka      2120002882                               Enkla problem
# ...         ...             ...                                         ...
# 5404  Österåker      2120002890                               Enkla problem
# 5405  Österåker      2120002890           Skriftliga räknemetoder, addition
# 5406  Österåker      2120002890        Skriftliga räknemetoder, subtraktion
# 5407  Österåker      2120002890               Mönster, matematiska likheter
# 5408  Österåker      2120002890  Huvudräkning och likhetstecknets betydelse
#
#      Skolan, totalt antal elever  \
# 0                             77
# 1                             77
# 2                             77
# 3                             77
# 4                             77
# ...                          ...
# 5404                          53
# 5405                          53
# 5406                          53
# 5407                          53
# 5408                          53
#
#      Skolan, andel som nått kravnivån av deltagande elever  \
# 0                                                   100
# 1                                                  95.9
# 2                                                  97.2
# 3                                                  95.9
# 4                                                  95.9
# ...                                                 ...
# 5404                                               98.1
# 5405                                                100
# 5406                                               98.1
# 5407                                                100
# 5408                                                100
#
#       Riket, andel som nått kravnivån av deltagande elever
# 0                                                  93.1
# 1                                                  86.3
# 2                                                  90.4
# 3                                                  88.8
# 4                                                  86.2
# ...                                                 ...
# 5404                                               86.2
# 5405                                               89.3
# 5406                                               79.2
# 5407                                               94.3
# 5408                                               91.0
#
# [5409 rows x 11 columns]

# %%
[df_dict[k]['Skol-enhetskod'].nunique() for k in df_dict.keys()]
# Out:
# [601, 609, 609, 586, 589, 583, 302, 270, 315]

# %%
years = [2019, 2018, 2017]
grade = 6
subjects = ['English', 'Math', 'Swedish', 'Swedish_as_a_second_language']

for i, s in enumerate(subjects):
    for year in years:
        title = f'{year}_grade-{grade}_{s}'
        df_dict[title] = pd.read_excel(f'data/exp_ap{grade}_2013_{year}.xlsx',
                                   sheet_name=i, 
                                   header=7
                                  )

# %%
df_dict.keys()
# Out:
# dict_keys(['2019_grade-3_Math', '2018_grade-3_Math', '2017_grade-3_Math', '2019_grade-3_Swedish', '2018_grade-3_Swedish', '2017_grade-3_Swedish', '2019_grade-3_Swedish_as_a_second_language', '2018_grade-3_Swedish_as_a_second_language', '2017_grade-3_Swedish_as_a_second_language', '2019_grade-6_English', '2018_grade-6_English', '2017_grade-6_English', '2019_grade-6_Math', '2018_grade-6_Math', '2017_grade-6_Math', '2019_grade-6_Swedish', '2018_grade-6_Swedish', '2017_grade-6_Swedish', '2019_grade-6_Swedish_as_a_second_language', '2018_grade-6_Swedish_as_a_second_language', '2017_grade-6_Swedish_as_a_second_language'])

# %%
school_codes = set()
for tmp_codes in [df_dict[k]['Skol-enhetskod'].unique() for k in df_dict.keys()]:
    for code in tmp_codes:
        school_codes.add(code)

# %%
len(school_codes)
# Out:
# 753

# %% [markdown]
# # Download [skolenhetsregistret](https://www.skolverket.se/skolutveckling/statistik/skoladresser-fran-skolenhetsregistret)

# %%
school_info = pd.read_excel(f'data/Skolenhetsregistret_20220602.xlsx',
                                   sheet_name='Grundskola'
                                  )

school_info.head()
# Out:
#   HUVUDMANNATYP  ORGANISATIONSNR  LÄN        LÄNSNAMN  KOMMUN      KOMMUNNAMN  \
# 0      Kommunal       2120000019    1  Stockholms län     114  Upplands Väsby
# 1      Kommunal       2120000019    1  Stockholms län     114  Upplands Väsby
# 2       Enskild       8160005966    1  Stockholms län     114  Upplands Väsby
# 3       Enskild       5567243547    1  Stockholms län     114  Upplands Väsby
# 4      Kommunal       2120000019    1  Stockholms län     114  Upplands Väsby
#
#    SKOLENHETSKOD               SKOLENHETENS NAMN           ADRESS  POSTNR  \
# 0       74174879                Bollstanäs skola   Stora vägen 80   19468
# 1       55512387                   Breddenskolan  Bergsyravägen 3   19464
# 2       80509560  Engelska skolan Upplands Väsby  Ryttargatan 275   19471
# 3       62078083                    Frestaskolan         Box 5017   19405
# 4       44227469                   Grimstaskolan       Vårvägen 1   19464
#
#    ... ÅR5 ÅR6  ÅR7 ÅR8 ÅR9                                  HUVUDMANS NAMN  \
# 0  ...   J   N    N   N   N                           UPPLANDS VÄSBY KOMMUN
# 1  ...   J   N    N   N   N                           UPPLANDS VÄSBY KOMMUN
# 2  ...   J   J    J   J   J         STIFTELSEN SPRÅKSKOLAN I UPPLANDS VÄSBY
# 3  ...   J   N    N   N   N  Lärande förskolor och grundskolor i Sverige AB
# 4  ...   N   J    J   J   J                           UPPLANDS VÄSBY KOMMUN
#
#              REKTORS NAMN INRIKTNING  \
# 0  Susanne Isaksson (t.f)        NaN
# 1             Lena Fridén        NaN
# 2              Maija Vola     Allmän
# 3      Elisabeth Brandell     Allmän
# 4     Monica Haag Gunnars        NaN
#
#   BEGRÄSAT MOTTAGADE TILL ELEVER I BEHOV AV SÄRSKILT STÖD  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                        JURIDISK FORM
# 0                                           Kommuner
# 1                                           Kommuner
# 2  Övriga stiftelser och fonder, inkl pensionssti...
# 3    Aktiebolag utom bank- och försäkringsaktiebolag
# 4                                           Kommuner
#
# [5 rows x 32 columns]

# %%
relevant_school_info = school_info.query('SKOLENHETSKOD in @school_codes & ÅR6 == "J"')
relevant_school_info.head()
# Out:
#    HUVUDMANNATYP  ORGANISATIONSNR  LÄN        LÄNSNAMN  KOMMUN  \
# 2        Enskild       8160005966    1  Stockholms län     114
# 4       Kommunal       2120000019    1  Stockholms län     114
# 9       Kommunal       2120000019    1  Stockholms län     114
# 10       Enskild       8160005966    1  Stockholms län     114
# 11       Enskild       5567220347    1  Stockholms län     114
#
#         KOMMUNNAMN  SKOLENHETSKOD               SKOLENHETENS NAMN  \
# 2   Upplands Väsby       80509560  Engelska skolan Upplands Väsby
# 4   Upplands Väsby       44227469                   Grimstaskolan
# 9   Upplands Väsby       77624936                     Runby skola
# 10  Upplands Väsby       68403656    Sverigefinska sk, Uppl Väsby
# 11  Upplands Väsby       49021135                  Södervikskolan
#
#               ADRESS  POSTNR  ... ÅR5 ÅR6  ÅR7 ÅR8 ÅR9  \
# 2    Ryttargatan 275   19471  ...   J   J    J   J   J
# 4         Vårvägen 1   19464  ...   N   J    J   J   J
# 9      Lövstavägen 1   19447  ...   J   J    J   J   J
# 10   Ryttargatan 275   19471  ...   J   J    J   J   J
# 11  Söderviksvägen 1   19454  ...   N   J    J   J   J
#
#                              HUVUDMANS NAMN         REKTORS NAMN INRIKTNING  \
# 2   STIFTELSEN SPRÅKSKOLAN I UPPLANDS VÄSBY           Maija Vola     Allmän
# 4                     UPPLANDS VÄSBY KOMMUN  Monica Haag Gunnars        NaN
# 9                     UPPLANDS VÄSBY KOMMUN       Johnny Wahlund        NaN
# 10  STIFTELSEN SPRÅKSKOLAN I UPPLANDS VÄSBY           Maija Vola     Allmän
# 11                        Södervikskolan AB      Carina Bergsten     Allmän
#
#    BEGRÄSAT MOTTAGADE TILL ELEVER I BEHOV AV SÄRSKILT STÖD  \
# 2                                                 NaN
# 4                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
#
#                                         JURIDISK FORM
# 2   Övriga stiftelser och fonder, inkl pensionssti...
# 4                                            Kommuner
# 9                                            Kommuner
# 10  Övriga stiftelser och fonder, inkl pensionssti...
# 11    Aktiebolag utom bank- och försäkringsaktiebolag
#
# [5 rows x 32 columns]

# %%
relevant_school_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 563 entries, 2 to 788
# Data columns (total 32 columns):
#  #   Column                                                   Non-Null Count  Dtype
# ---  ------                                                   --------------  -----
#  0   HUVUDMANNATYP                                            563 non-null    object
#  1   ORGANISATIONSNR                                          563 non-null    int64
#  2   LÄN                                                      563 non-null    int64
#  3   LÄNSNAMN                                                 563 non-null    object
#  4   KOMMUN                                                   563 non-null    int64
#  5   KOMMUNNAMN                                               563 non-null    object
#  6   SKOLENHETSKOD                                            563 non-null    int64
#  7   SKOLENHETENS NAMN                                        563 non-null    object
#  8   ADRESS                                                   560 non-null    object
#  9   POSTNR                                                   563 non-null    int64
#  10  POSTORT                                                  563 non-null    object
#  11  BESÖKSADRESS                                             563 non-null    object
#  12  BESÖKSPOSTNR                                             563 non-null    int64
#  13  BESÖKSPOSTORT                                            563 non-null    object
#  14  TELENR                                                   562 non-null    object
#  15  WEBB                                                     562 non-null    object
#  16  EPOST                                                    563 non-null    object
#  17  FKLASS                                                   563 non-null    object
#  18  ÅR1                                                      563 non-null    object
#  19  ÅR2                                                      563 non-null    object
#  20  ÅR3                                                      563 non-null    object
#  21  ÅR4                                                      563 non-null    object
#  22  ÅR5                                                      563 non-null    object
#  23  ÅR6                                                      563 non-null    object
#  24  ÅR7                                                      563 non-null    object
#  25  ÅR8                                                      563 non-null    object
#  26  ÅR9                                                      563 non-null    object
#  27  HUVUDMANS NAMN                                           563 non-null    object
#  28  REKTORS NAMN                                             563 non-null    object
#  29  INRIKTNING                                               191 non-null    object
#  30  BEGRÄSAT MOTTAGADE TILL ELEVER I BEHOV AV SÄRSKILT STÖD  28 non-null     object
#  31  JURIDISK FORM                                            563 non-null    object
# dtypes: int64(6), object(26)
# memory usage: 145.1+ KB

# %%
school_codes = relevant_school_info['SKOLENHETSKOD'].values

# %%
keys = list(df_dict.keys())

df_dict[keys[-1]]
# Out:
#                    Skola  Skol-enhetskod Skolkommun  Kommun-kod  \
# 0        Björkhaga Skola        43238662   Botkyrka         127
# 1        Björkhaga Skola        43238662   Botkyrka         127
# 2        Björkhaga Skola        43238662   Botkyrka         127
# 3        Björkhaga Skola        43238662   Botkyrka         127
# 4     Blåklintskolan 1GR        84891659   Botkyrka         127
# ...                  ...             ...        ...         ...
# 1263    Solskiftesskolan        82624830  Österåker         117
# 1264          Söraskolan        88712672  Österåker         117
# 1265          Söraskolan        88712672  Österåker         117
# 1266          Söraskolan        88712672  Österåker         117
# 1267          Söraskolan        88712672  Österåker         117
#
#      Typ av huvudman   Huvudman  Huvudman orgnr             Delprov Totalt  \
# 0           Kommunal   Botkyrka      2120002882           Provbetyg     ..
# 1           Kommunal   Botkyrka      2120002882    Tala (delprov A)     ..
# 2           Kommunal   Botkyrka      2120002882    Läsa (delprov B)     ..
# 3           Kommunal   Botkyrka      2120002882  Skriva (delprov C)     ..
# 4           Kommunal   Botkyrka      2120002882           Provbetyg      .
# ...              ...        ...             ...                 ...    ...
# 1263        Kommunal  Österåker      2120002890  Skriva (delprov C)     ..
# 1264        Kommunal  Österåker      2120002890           Provbetyg     ..
# 1265        Kommunal  Österåker      2120002890    Tala (delprov A)    100
# 1266        Kommunal  Österåker      2120002890    Läsa (delprov B)   92.3
# 1267        Kommunal  Österåker      2120002890  Skriva (delprov C)     ..
#
#      Flickor Pojkar Totalt  Flickor  Pojkar  Totalt   Flickor   Pojkar    \
# 0         ..     ..      ..       ..      ..       ..        ..       ..
# 1         ..     ..      ..       ..      ..       ..        ..       ..
# 2         ..     ..      ..       ..      ..       ..         .       ..
# 3         ..     ..      ..       ..      ..       ..        ..        .
# 4          .      .       .        .       .        .         .        .
# ...      ...    ...     ...      ...     ...      ...       ...      ...
# 1263       .     ..      ..        .      ..       ..         .       ..
# 1264      ..     ..      ..       ..      ..       ..        ..       ..
# 1265      ..     ..      13       ..      ..     ~100        ..       ..
# 1266      ..     ..      12       ..      ..       ..        ..       ..
# 1267      ..     ..      ..       ..      ..       ..        ..       ..
#
#      Totalt    Flickor    Pojkar
# 0           ..         ..        ..
# 1           ..         ..        ..
# 2           ..         ..        ..
# 3           ..         ..        ..
# 4            .          .         .
# ...        ...        ...       ...
# 1263        ..          .        ..
# 1264        ..         ..        ..
# 1265       9.2         ..        ..
# 1266       8.1         ..        ..
# 1267        ..         ..        ..
#
# [1268 rows x 20 columns]

# %% [markdown]
# # Grade 6
#
# Focus on the sixth grade because the statistics gives absolute score for each subject.
#
# Use the "Genomsnittlig provbetygspoäng" column.
# The description of the columns:
#
# >The average test score shows an average of the students' test scores converted into points. The average test score is calculated for pupils who have obtained test grades A-F in the respective section or subject tests. The grade F gives 0 points, E gives 10 points, D gives 12.5, C gives 15, B gives 17.5 and A gives 20 points. The highest possible test mark is 20 points and the lowest is 0 points.
#
# - `columns[-9]` corresponds to the number of students.
# -  `columns[-3]` corresponds to the score.
#
# These columns have the same name "Totalt" due to the excel column structure.

# %%
import numpy as np

years = [2019, 2018, 2017]
grade = 6
subjects = ['English', 'Math', 'Swedish', 'Swedish_as_a_second_language']

info_cols = ['SKOLENHETSKOD', 'HUVUDMANNATYP', 'KOMMUNNAMN', 'SKOLENHETENS NAMN', 'BESÖKSADRESS', 'BESÖKSPOSTNR', 'BESÖKSPOSTORT', 'WEBB', 'FKLASS']

summary_dict = {}

for i, s in enumerate(subjects):
    summary_dict[s] = []
    for year in years:
        title = f'{year}_grade-{grade}_{s}'
        cols = ['Skol-enhetskod', 'Delprov'] + [df_dict[title].columns[-9]] + [df_dict[title].columns[-3]]
        renamed_cols = ['school_code', 'subtest', 'num_students', 'score']
        tmp_df = df_dict[title][cols].rename(columns={
            k:v for k,v in zip(cols, renamed_cols)
        })
        tmp_df['score'] = tmp_df['score'].replace('.', np.nan).replace('..', np.nan).astype(float)
        tmp_df = tmp_df.pivot(index='school_code', columns='subtest', values='score')
        tmp_df['avg_score'] = tmp_df.mean(axis=1, skipna=True)
        tmp_df = tmp_df.merge(relevant_school_info[info_cols], left_on='school_code', right_on='SKOLENHETSKOD', how='inner')
        tmp_df['year'] = year
        summary_dict[s].append(tmp_df)
    summary_dict[s] = pd.concat(summary_dict[s]).reset_index(drop=True)

# %%
summary_dict['Swedish'].head()
# Out:
#    Läsa (delprov B)  Provbetyg  Skriva (delprov C)  Tala (delprov A)  \
# 0              14.3       12.9                11.6              13.8
# 1              14.1       13.3                11.6              14.6
# 2              13.8       15.4                15.6              16.5
# 3              11.6       13.8                12.9              15.3
# 4               NaN        NaN                 NaN               NaN
#
#    avg_score  SKOLENHETSKOD HUVUDMANNATYP  KOMMUNNAMN  SKOLENHETENS NAMN  \
# 0     13.150       10063280       Enskild    Huddinge        Skapaskolan
# 1     13.400       10225038      Kommunal    Huddinge     Solfagraskolan
# 2     15.325       10360193       Enskild   Stockholm       Profilskolan
# 3     13.400       10661388       Enskild  Södertälje  Örjanskolan grund
# 4        NaN       10682125       Enskild   Stockholm       Magitaskolan
#
#             BESÖKSADRESS  BESÖKSPOSTNR BESÖKSPOSTORT  \
# 0       Midsommarvägen 4         14144      Huddinge
# 1       Prästvägen 23-25         14131      Huddinge
# 2  Krossgatan 34, plan 4         16250     Vällingby
# 3                 Nibble         15391         Järna
# 4       Sjöbjörnsvägen 5         11767     Stockholm
#
#                                     WEBB FKLASS  year
# 0              http://www.skapaskolan.se      J  2019
# 1  http://www.huddinge.se/solfagraskolan      J  2019
# 2             http://www.profilskolan.se      J  2019
# 3              http://www.orjanskolan.se      J  2019
# 4             http://www.magitaskolan.se      J  2019

# %%
tmp_list = []

for i, s in enumerate(subjects):
    tmp_df = (
        summary_dict[s]
        .groupby('SKOLENHETSKOD')['avg_score']
        .apply(lambda x:x.mean(skipna=True))
        .reset_index()
        .rename(columns={'avg_score': f'{s}_avg_score'})
    )
    tmp_list.append(tmp_df)

avg_df = tmp_list[0]
for elm in tmp_list[1:]:
    avg_df = avg_df.merge(elm, on='SKOLENHETSKOD', how='outer')
avg_df['grand_avg_score'] = avg_df[avg_df.columns[avg_df.columns.str.endswith('score')]].mean(axis=1, skipna=True)
avg_df = avg_df.merge(relevant_school_info[info_cols], on='SKOLENHETSKOD')
avg_df = avg_df.dropna(subset=['grand_avg_score']).reset_index(drop=True)
avg_df.sort_values('grand_avg_score', ascending=False)
# Out:
#      SKOLENHETSKOD  English_avg_score  Math_avg_score  Swedish_avg_score  \
# 257       57106833          17.725000       17.000000          18.900000
# 198       45553352          19.233333       16.766667          16.475000
# 133       36066067          17.925000       17.066667          16.958333
# 297       64065082          19.000000       16.733333          16.108333
# 492       99648792          18.350000       16.066667          16.866667
# ..             ...                ...             ...                ...
# 230       51210001          11.916667        6.300000          10.308333
# 486       98515782           9.508333        8.500000           5.808333
# 401       82838118           9.275000        5.200000           6.850000
# 273       59457803                NaN             NaN           4.800000
# 13        12092203           4.625000        4.200000           2.800000
#
#      Swedish_as_a_second_language_avg_score  grand_avg_score HUVUDMANNATYP  \
# 257                                     NaN        17.875000       Enskild
# 198                                     NaN        17.491667       Enskild
# 133                                     NaN        17.316667       Enskild
# 297                                     NaN        17.280556       Enskild
# 492                                     NaN        17.094444      Kommunal
# ..                                      ...              ...           ...
# 230                                3.566667         8.022917      Kommunal
# 486                                     NaN         7.938889       Enskild
# 401                                3.000000         6.081250       Enskild
# 273                                     NaN         4.800000       Enskild
# 13                                      NaN         3.875000      Kommunal
#
#      KOMMUNNAMN               SKOLENHETENS NAMN            BESÖKSADRESS  \
# 257    Danderyd              Vendestigens skola         Vendevägen 30 A
# 198   Stockholm  Montessori Mondial Kungsholmen    Konradsbergsgatan 24
# 133   Stockholm     Musikskolan Lilla Akademien       Norrtullsgatan 14
# 297   Stockholm       Fredrikshovs slotts skola     Fredrikshovsgatan 6
# 492   Stockholm     Adolf Fredriks musikklasser       Tegnérgatan 44-46
# ..          ...                             ...                     ...
# 230  Södertälje                     Ronnaskolan  Robert Anbergs väg 1-3
# 486       Solna           Ängkärrskolan i Solna         Ängkärrsgatan 9
# 401   Stockholm       Alla Nationers Fria Skola       Vårbergsvägen 63B
# 273   Österåker      Helleborusskolan Österåker          Luffarbacken 5
# 13   Sollentuna  Brage- skola och språkförskola      Hertig Karls väg 5
#
#      BESÖKSPOSTNR BESÖKSPOSTORT  \
# 257         18262     Djursholm
# 198         11259     Stockholm
# 133         11345     Stockholm
# 297         11523     Stockholm
# 492         11329     Stockholm
# ..            ...           ...
# 230         15153    Södertälje
# 486         17170         Solna
# 401         12743    Skärholmen
# 273         18439    Åkersberga
# 13          19268    Sollentuna
#
#                                                   WEBB FKLASS
# 257                          http://www.vendestigen.se      J
# 198                                http://www.stims.se      J
# 133                       http://www.lillaakademien.se      J
# 297                          http://www.fredrikshov.se      J
# 492  https://grundskola.stockholm/hitta-grundskola/...      N
# ..                                                 ...    ...
# 230               http://www.sodertalje.se/ronnaskolan      J
# 486                        http://www.angkarrskolan.se      N
# 401                                 http://www.anfs.se      J
# 273                     http://www.helleborusskolan.se      J
# 13                    http://www.talochsprakcentrum.se      J
#
# [494 rows x 14 columns]

# %% [markdown]
# # School location
#
# - Need to enable the Google Place api

# %%
test = ' '.join(avg_df.iloc[0][['SKOLENHETENS NAMN', 'BESÖKSPOSTNR', 'BESÖKSADRESS', 'BESÖKSPOSTORT']].astype(str).values) + ' Sweden'
print(test)
test.replace(' ', '%20')
# Out:
# Skapaskolan 14144 Midsommarvägen 4 Huddinge Sweden
# 'Skapaskolan%2014144%20Midsommarvägen%204%20Huddinge%20Sweden'

# %%
import requests
import os

API_KEY = os.environ['API_KEY']
address = test.replace(' ', '%20')
url = f'https://maps.googleapis.com/maps/api/geocode/json?address={address}&key={API_KEY}'

payload={}
headers = {}

response = requests.request("GET", url, headers=headers, data=payload)

print(response.text)
# Out:
# {
#    "results" : [
#       {
#          "address_components" : [
#             {
#                "long_name" : "4",
#                "short_name" : "4",
#                "types" : [ "street_number" ]
#             },
#             {
#                "long_name" : "Midsommarvägen",
#                "short_name" : "Midsommarvägen",
#                "types" : [ "route" ]
#             },
#             {
#                "long_name" : "Flemingsberg",
#                "short_name" : "Flemingsberg",
#                "types" : [ "political", "sublocality", "sublocality_level_1" ]
#             },
#             {
#                "long_name" : "Huddinge",
#                "short_name" : "Huddinge",
#                "types" : [ "postal_town" ]
#             },
#             {
#                "long_name" : "Stockholms län",
#                "short_name" : "Stockholms län",
#                "types" : [ "administrative_area_level_1", "political" ]
#             },
#             {
#                "long_name" : "Sweden",
#                "short_name" : "SE",
#                "types" : [ "country", "political" ]
#             },
#             {
#                "long_name" : "141 44",
#                "short_name" : "141 44",
#                "types" : [ "postal_code" ]
#             }
#          ],
#          "formatted_address" : "Midsommarvägen 4, 141 44 Huddinge, Sweden",
#          "geometry" : {
#             "location" : {
#                "lat" : 59.232791,
#                "lng" : 17.9576796
#             },
#             "location_type" : "ROOFTOP",
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 59.2341211302915,
#                   "lng" : 17.9588905802915
#                },
#                "southwest" : {
#                   "lat" : 59.23142316970849,
#                   "lng" : 17.9561926197085
#                }
#             }
#          },
#          "partial_match" : true,
#          "place_id" : "ChIJtZQoMNpwX0YRtR4BNuHwRMc",
#          "plus_code" : {
#             "compound_code" : "6XM5+43 Huddinge, Sweden",
#             "global_code" : "9FFV6XM5+43"
#          },
#          "types" : [ "street_address" ]
#       },
#       {
#          "address_components" : [
#             {
#                "long_name" : "Huddinge",
#                "short_name" : "Huddinge",
#                "types" : [ "postal_town" ]
#             },
#             {
#                "long_name" : "Flemingsberg",
#                "short_name" : "Flemingsberg",
#                "types" : [ "political", "sublocality", "sublocality_level_1" ]
#             },
#             {
#                "long_name" : "Stockholms län",
#                "short_name" : "Stockholms län",
#                "types" : [ "administrative_area_level_1", "political" ]
#             },
#             {
#                "long_name" : "Sweden",
#                "short_name" : "SE",
#                "types" : [ "country", "political" ]
#             },
#             {
#                "long_name" : "141 32",
#                "short_name" : "141 32",
#                "types" : [ "postal_code" ]
#             }
#          ],
#          "formatted_address" : "141 32 Huddinge, Sweden",
#          "geometry" : {
#             "location" : {
#                "lat" : 59.2336677,
#                "lng" : 17.9604015
#             },
#             "location_type" : "GEOMETRIC_CENTER",
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 59.23492133029151,
#                   "lng" : 17.9617339302915
#                },
#                "southwest" : {
#                   "lat" : 59.23222336970849,
#                   "lng" : 17.9590359697085
#                }
#             }
#          },
#          "partial_match" : true,
#          "place_id" : "ChIJAQAAADRxX0YRsKENh-Js6J4",
#          "plus_code" : {
#             "compound_code" : "6XM6+F5 Huddinge, Sweden",
#             "global_code" : "9FFV6XM6+F5"
#          },
#          "types" : [ "establishment", "point_of_interest", "school" ]
#       }
#    ],
#    "status" : "OK"
# }

# %%
import json

res = json.loads(response.text)
res['results'][0]['geometry']['location']
# Out:
# {'lat': 59.232791, 'lng': 17.9576796}

# %%
import requests
import os

API_KEY = os.environ['API_KEY']
address = test.replace(' ', '%20')
url = f'https://maps.googleapis.com/maps/api/place/findplacefromtext/json?input={address}&inputtype=textquery&fields=rating%2Cgeometry&key={API_KEY}'

payload={}
headers = {}

response = requests.request("GET", url, headers=headers, data=payload)

print(response.text)
# Out:
# {
#    "candidates" : [
#       {
#          "geometry" : {
#             "location" : {
#                "lat" : 59.2336677,
#                "lng" : 17.9604016
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 59.23492217989272,
#                   "lng" : 17.96173482989273
#                },
#                "southwest" : {
#                   "lat" : 59.23222252010728,
#                   "lng" : 17.95903517010728
#                }
#             }
#          },
#          "rating" : 2.4
#       }
#    ],
#    "status" : "OK"
# }

# %%
res = json.loads(response.text)
res['candidates'][0]['geometry']['location']
# Out:
# {'lat': 59.2336677, 'lng': 17.9604016}

# %%
res['candidates'][0]['rating']
# Out:
# 2.4

# %%
import json
from tqdm import tqdm
import requests
import os

API_KEY = os.environ['API_KEY']
lats = []
lons = []
ratings = []

for i, row in tqdm(avg_df.iterrows(), total=len(avg_df)):
    s = ' '.join(row[['SKOLENHETENS NAMN', 'BESÖKSPOSTNR', 'BESÖKSADRESS', 'BESÖKSPOSTORT']].astype(str).values) + ' Sweden'
    address = s.replace(' ', '%20')
    url = f'https://maps.googleapis.com/maps/api/place/findplacefromtext/json?input={address}&inputtype=textquery&fields=rating%2Cgeometry&key={API_KEY}'

    payload={}
    headers = {}

    response = requests.request("GET", url, headers=headers, data=payload)
    res = json.loads(response.text)
        
    if len(res['candidates']) == 0:
        print(i)
        url = f'https://maps.googleapis.com/maps/api/geocode/json?address={address}&key={API_KEY}'
        payload={}
        headers = {}
        response = requests.request("GET", url, headers=headers, data=payload)
        res = json.loads(response.text)
        try:
            loc = res['results'][0]['geometry']['location']
        except:
            loc = {'lat': np.nan, 'lng':np.nan}
        
        lats.append(loc['lat'])
        lons.append(loc['lng'])
        ratings.append(np.nan)
    else:   
        loc = res['candidates'][0]['geometry']['location']
        lats.append(loc['lat'])
        lons.append(loc['lng'])
        try:
            ratings.append(res['candidates'][0]['rating'])
        except:
            ratings.append(np.nan)
# Out:
#  10%|▉         | 47/494 [00:36<07:47,  1.05s/it]
# 47
#  26%|██▌       | 128/494 [01:37<04:30,  1.35it/s]
# 127
#  43%|████▎     | 214/494 [02:40<03:09,  1.48it/s]
# 213
#  46%|████▌     | 227/494 [02:49<03:03,  1.46it/s]
# 227
#  62%|██████▏   | 305/494 [03:44<02:18,  1.37it/s]
# 304
#  75%|███████▌  | 371/494 [04:31<01:24,  1.45it/s]
# 371
# 100%|██████████| 494/494 [05:58<00:00,  1.38it/s]

# %%
avg_df['lon'] = lons
avg_df['lat'] = lats
avg_df['Google_rating'] = ratings

avg_df.head()
# Out:
#    SKOLENHETSKOD  English_avg_score  Math_avg_score  Swedish_avg_score  \
# 0       10063280          14.125000        9.833333          12.308333
# 1       10225038          15.550000       14.133333          12.983333
# 2       10360193          15.550000       12.600000          15.700000
# 3       10661388          11.883333       10.166667          14.191667
# 4       10715898          16.333333       13.200000          14.900000
#
#    Swedish_as_a_second_language_avg_score  grand_avg_score HUVUDMANNATYP  \
# 0                                     NaN        12.088889       Enskild
# 1                                     NaN        14.222222      Kommunal
# 2                                     NaN        14.616667       Enskild
# 3                                     NaN        12.080556       Enskild
# 4                                     NaN        14.811111       Enskild
#
#    KOMMUNNAMN  SKOLENHETENS NAMN           BESÖKSADRESS  BESÖKSPOSTNR  \
# 0    Huddinge        Skapaskolan       Midsommarvägen 4         14144
# 1    Huddinge     Solfagraskolan       Prästvägen 23-25         14131
# 2   Stockholm       Profilskolan  Krossgatan 34, plan 4         16250
# 3  Södertälje  Örjanskolan grund                 Nibble         15391
# 4   Österåker     Akers Friskola           Svampvägen 4         18438
#
#   BESÖKSPOSTORT                                   WEBB FKLASS        lon  \
# 0      Huddinge              http://www.skapaskolan.se      J  17.960402
# 1      Huddinge  http://www.huddinge.se/solfagraskolan      J  18.009328
# 2     Vällingby             http://www.profilskolan.se      J  17.856736
# 3         Järna              http://www.orjanskolan.se      J  17.616505
# 4    Åkersberga            http://www.akersfriskola.se      J  18.332378
#
#          lat  Google_rating
# 0  59.233668            2.4
# 1  59.239366            3.8
# 2  59.372352            3.5
# 3  59.066291            3.8
# 4  59.491625            4.0

# %%
avg_df['Google_rating'] = avg_df['Google_rating'].apply(lambda x: np.nan if x==0 else x)

# %%
avg_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 494 entries, 0 to 493
# Data columns (total 17 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   SKOLENHETSKOD                           494 non-null    int64
#  1   English_avg_score                       493 non-null    float64
#  2   Math_avg_score                          492 non-null    float64
#  3   Swedish_avg_score                       463 non-null    float64
#  4   Swedish_as_a_second_language_avg_score  123 non-null    float64
#  5   grand_avg_score                         494 non-null    float64
#  6   HUVUDMANNATYP                           494 non-null    object
#  7   KOMMUNNAMN                              494 non-null    object
#  8   SKOLENHETENS NAMN                       494 non-null    object
#  9   BESÖKSADRESS                            494 non-null    object
#  10  BESÖKSPOSTNR                            494 non-null    int64
#  11  BESÖKSPOSTORT                           494 non-null    object
#  12  WEBB                                    494 non-null    object
#  13  FKLASS                                  494 non-null    object
#  14  lon                                     494 non-null    float64
#  15  lat                                     494 non-null    float64
#  16  Google_rating                           467 non-null    float64
# dtypes: float64(8), int64(2), object(7)
# memory usage: 65.7+ KB

# %%
avg_df.to_csv('data/avg_df.csv', index=False)

# %% [markdown]
# # Draw map

# %%
import pandas as pd

avg_df = pd.read_csv('data/avg_df.csv')
avg_df.head()
# Out:
#    SKOLENHETSKOD  English_avg_score  Math_avg_score  Swedish_avg_score  \
# 0       10063280          14.125000        9.833333          12.308333
# 1       10225038          15.550000       14.133333          12.983333
# 2       10360193          15.550000       12.600000          15.700000
# 3       10661388          11.883333       10.166667          14.191667
# 4       10715898          16.333333       13.200000          14.900000
#
#    Swedish_as_a_second_language_avg_score  grand_avg_score HUVUDMANNATYP  \
# 0                                     NaN        12.088889       Enskild
# 1                                     NaN        14.222222      Kommunal
# 2                                     NaN        14.616667       Enskild
# 3                                     NaN        12.080556       Enskild
# 4                                     NaN        14.811111       Enskild
#
#    KOMMUNNAMN  SKOLENHETENS NAMN           BESÖKSADRESS  BESÖKSPOSTNR  \
# 0    Huddinge        Skapaskolan       Midsommarvägen 4         14144
# 1    Huddinge     Solfagraskolan       Prästvägen 23-25         14131
# 2   Stockholm       Profilskolan  Krossgatan 34, plan 4         16250
# 3  Södertälje  Örjanskolan grund                 Nibble         15391
# 4   Österåker     Akers Friskola           Svampvägen 4         18438
#
#   BESÖKSPOSTORT                                   WEBB FKLASS        lon  \
# 0      Huddinge              http://www.skapaskolan.se      J  17.960402
# 1      Huddinge  http://www.huddinge.se/solfagraskolan      J  18.009328
# 2     Vällingby             http://www.profilskolan.se      J  17.856736
# 3         Järna              http://www.orjanskolan.se      J  17.616505
# 4    Åkersberga            http://www.akersfriskola.se      J  18.332378
#
#          lat  Google_rating
# 0  59.233668            2.4
# 1  59.239366            3.8
# 2  59.372352            3.5
# 3  59.066291            3.8
# 4  59.491625            4.0

# %%
from uuid import uuid4
from unfolded.map_sdk import UnfoldedMap

dataset_id = uuid4()
unfolded_map = UnfoldedMap(width='100%', height='90vh')

unfolded_map
# Out:
# UnfoldedMap(height='90vh')

# %%
unfolded_map.add_dataset({
    'uuid': dataset_id,
    'label': 'school_analysis',
    'data': avg_df,
    },
    auto_create_layers=False)

unfolded_map.add_layer({
    'id': 'grand_average',
    'type': 'point', 
    'config': {
        'color': [18, 147, 154],
        'column_mode': 'points',
        'columns': {'lat': 'lat', 'lng': 'lon'},
        'dataId': dataset_id,
        'hidden': False,
        'is_visible': True,
        'label': 'grand_average',
        }
    })

unfolded_map.add_layer({
    'id': 'math',
    'type': 'point', 
    'config': {
        'color': [18, 147, 154],
        'column_mode': 'points',
        'columns': {'lat': 'lat', 'lng': 'lon'},
        'dataId': dataset_id,
        'hidden': False,
        'is_visible': False,
        'label': 'math',
        }
    })

# unfolded_map.add_layer({
#     'id': 'Google_rating',
#     'type': 'point', 
#     'config': {
#         'color': [18, 147, 154],
#         'column_mode': 'points',
#         'columns': {'lat': 'lat', 'lng': 'lon'},
#         'dataId': dataset_id,
#         'hidden': False,
#         'is_visible': False,
#         'label': 'Google_rating',
#         }
#     })

unfolded_map.set_view_state({
    'longitude': 18.44,
     'latitude': 59.23,
     'zoom': 7.75,
     })

unfolded_map.set_map_config({
  'version': 'v1',
  'config': {
      'mapStyle': {'backgroundColor': [255, 255, 255],
                   'mapStyles': {},
                   'styleType': 'streets',
      },
      'visState': {'analyses': [],
                    'animationConfig': {'currentTime': None, 'speed': 1},
                    'charts': [],
                    'datasets': {'datasetColors': {dataset_id: [0,
                                                                 92,
                                                                 255]},
                              'fieldDisplayNames': {dataset_id: {}}},
                    'editor': {'features': [], 'visible': True},
                    'filters': [],
                    'geoKeys': [],
                    'groupBys': [],
                    'interactionConfig': {'brush': {'enabled': False, 'size': 0.5},
                                       'coordinate': {'enabled': False},
                                       'geocoder': {'enabled': False},
                                       'tooltip': {'compareMode': False,
                                                   'compareType': 'absolute',
                                                   'enabled': True,
                                                   'fieldsToShow': {dataset_id: [
                                                                                 {'format': None,
                                                                                  'name': 'SKOLENHETENS '
                                                                                          'NAMN'},
                                                                                 {'format': None,
                                                                                  'name': 'grand_avg_score'},
                                                                                 {'format': None,
                                                                                  'name': 'English_avg_score'},
                                                                                 {'format': None,
                                                                                  'name': 'Math_avg_score'},
                                                                                 {'format': None,
                                                                                  'name': 'Swedish_avg_score'},
                                                                                 {'format': None,
                                                                                  'name': 'Swedish_as_a_second_language_avg_score'},
                                                                                 {'format': None,
                                                                                  'name': 'Google_rating'},
                                                                                 {'format': None,
                                                                                  'name': 'HUVUDMANNATYP'},
                                                                                 {'format': None,
                                                                                  'name': 'KOMMUNNAMN'},
                                                                                 {'format': None,
                                                                                  'name': 'WEBB'},
                                                                                 {'format': None,
                                                                                  'name': 'FKLASS'}]}}},
                    'joins': [],
                    'layerBlending': 'normal',
                    'layers': [{'config': {'color': [179, 173, 158],
                        'columnMode': 'points',
                        'columns': {'lat': 'lat', 'lng': 'lon'},
                        'dataId': dataset_id,
                        'hidden': False,
                        'isVisible': False,
                        'label': 'math',
                        'textLabel': [{'alignment': 'center',
                                       'anchor': 'start',
                                       'color': [255, 255, 255],
                                       'field': [],
                                       'offset': [0, 0],
                                       'size': 18}],
                        'visConfig': {'allowHover': True,
                                      'billboard': False,
                                      'colorRange': {'category': 'ColorBrewer',
                                                     'colors': ['#A50026',
                                                                '#F88D52',
                                                                '#FAF8C1',
                                                                '#90C2DD',
                                                                '#313695'],
                                                     'name': 'RdYlBu',
                                                     'type': 'diverging'},
                                      'filled': True,
                                      'fixedRadius': False,
                                      'opacity': 0.5,
                                      'outline': False,
                                      'radius': 10,
                                      'radiusRange': [5, 50],
                                      'showHighlightColor': True,
                                      'showNeighborOnHover': False,
                                      'strokeColor': None,
                                      'strokeColorRange': {'category': 'Uber',
                                                           'colors': ['#4C0035',
                                                                      '#880030',
                                                                      '#B72F15',
                                                                      '#D6610A',
                                                                      '#EF9100',
                                                                      '#FFC300'],
                                                           'name': 'Global '
                                                                   'Warming',
                                                           'type': 'sequential'},
                                      'thickness': 2}},
             'id': 'ih1xeqf',
             'type': 'point',
             'visualChannels': {'colorField': {'name': 'Math_avg_score',
                                               'type': 'real'},
                                'colorScale': 'quantile',
                                'sizeField': {'name': 'Google_rating',
                                              'type': 'real'},
                                'sizeScale': 'sqrt',
                                'strokeColorField': None,
                                'strokeColorScale': 'quantile'}},
            {'config': {'color': [179, 173, 158],
                        'columnMode': 'points',
                        'columns': {'lat': 'lat', 'lng': 'lon'},
                        'dataId': dataset_id,
                        'hidden': False,
                        'isVisible': True,
                        'label': 'grand_average',
                        'textLabel': [{'alignment': 'center',
                                       'anchor': 'start',
                                       'color': [255, 255, 255],
                                       'field': [],
                                       'offset': [0, 0],
                                       'size': 18}],
                        'visConfig': {'allowHover': True,
                                      'billboard': False,
                                      'colorRange': {'category': 'ColorBrewer',
                                                     'colors': ['#A50026',
                                                                '#F88D52',
                                                                '#FAF8C1',
                                                                '#90C2DD',
                                                                '#313695'],
                                                     'name': 'RdYlBu',
                                                     'type': 'diverging'},
                                      'filled': True,
                                      'fixedRadius': False,
                                      'opacity': 0.5,
                                      'outline': False,
                                      'radius': 10,
                                      'radiusRange': [5, 50],
                                      'showHighlightColor': True,
                                      'showNeighborOnHover': False,
                                      'strokeColor': None,
                                      'strokeColorRange': {'category': 'Uber',
                                                           'colors': ['#4C0035',
                                                                      '#880030',
                                                                      '#B72F15',
                                                                      '#D6610A',
                                                                      '#EF9100',
                                                                      '#FFC300'],
                                                           'name': 'Global '
                                                                   'Warming',
                                                           'type': 'sequential'},
                                      'thickness': 2}},
             'id': 'pijyjo',
             'type': 'point',
             'visualChannels': {'colorField': {'name': 'grand_avg_score',
                                               'type': 'real'},
                                'colorScale': 'quantile',
                                'sizeField': {'name': 'Google_rating',
                                              'type': 'real'},
                                'sizeScale': 'sqrt',
                                'strokeColorField': None,
                                'strokeColorScale': 'quantile'}}],
                    'metrics': [],
                    'overlayBlending': 'normal',
                    'splitMaps': []}
  }
})
# Out:
# <Future pending>

# %%
config = unfolded_map.get_map_config()

# %%
from pprint import pprint

pprint(dict(config.result())['config'].visState)
# Out:
# {'analyses': [],
#  'animationConfig': {'currentTime': None, 'speed': 1},
#  'charts': [],
#  'datasets': {'datasetColors': {'b75b865b-454e-42c7-b27e-8a0493754aba': [0,
#                                                                          92,
#                                                                          255]},
#               'fieldDisplayNames': {'b75b865b-454e-42c7-b27e-8a0493754aba': {}}},
#  'editor': {'features': [], 'visible': True},
#  'filters': [{'animationWindow': 'free',
#               'dataId': ['b75b865b-454e-42c7-b27e-8a0493754aba'],
#               'enabled': True,
#               'id': 'ld9rb5pyl',
#               'name': ['grand_avg_score'],
#               'plotType': {'type': 'histogram'},
#               'speed': 1,
#               'type': 'range',
#               'value': [15, 17.88],
#               'view': 'side',
#               'yAxis': None}],
#  'geoKeys': [],
#  'groupBys': [],
#  'interactionConfig': {'brush': {'enabled': False, 'size': 0.5},
#                        'coordinate': {'enabled': False},
#                        'geocoder': {'enabled': False},
#                        'tooltip': {'compareMode': False,
#                                    'compareType': 'absolute',
#                                    'enabled': True,
#                                    'fieldsToShow': {'b75b865b-454e-42c7-b27e-8a0493754aba': [{'name': 'SKOLENHETENS '
#                                                                                                       'NAMN'},
#                                                                                              {'name': 'grand_avg_score'},
#                                                                                              {'name': 'English_avg_score'},
#                                                                                              {'name': 'Math_avg_score'},
#                                                                                              {'name': 'Swedish_avg_score'},
#                                                                                              {'name': 'Swedish_as_a_second_language_avg_score'},
#                                                                                              {'name': 'Google_rating'},
#                                                                                              {'name': 'HUVUDMANNATYP'},
#                                                                                              {'name': 'KOMMUNNAMN'},
#                                                                                              {'name': 'WEBB'},
#                                                                                              {'name': 'FKLASS'}]}}},
#  'joins': [],
#  'layerBlending': 'normal',
#  'layers': [{'config': {'color': [179, 173, 158],
#                         'columnMode': 'points',
#                         'columns': {'lat': 'lat', 'lng': 'lon'},
#                         'dataId': 'b75b865b-454e-42c7-b27e-8a0493754aba',
#                         'hidden': False,
#                         'isVisible': False,
#                         'label': 'math',
#                         'textLabel': [{'alignment': 'center',
#                                        'anchor': 'start',
#                                        'color': [255, 255, 255],
#                                        'field': [],
#                                        'offset': [0, 0],
#                                        'size': 18}],
#                         'visConfig': {'allowHover': True,
#                                       'billboard': False,
#                                       'colorRange': {'category': 'ColorBrewer',
#                                                      'colors': ['#A50026',
#                                                                 '#F88D52',
#                                                                 '#FAF8C1',
#                                                                 '#90C2DD',
#                                                                 '#313695'],
#                                                      'name': 'RdYlBu',
#                                                      'type': 'diverging'},
#                                       'filled': True,
#                                       'fixedRadius': False,
#                                       'opacity': 0.5,
#                                       'outline': False,
#                                       'radius': 10,
#                                       'radiusRange': [0, 20],
#                                       'showHighlightColor': True,
#                                       'showNeighborOnHover': False,
#                                       'strokeColor': None,
#                                       'strokeColorRange': {'category': 'Uber',
#                                                            'colors': ['#4C0035',
#                                                                       '#880030',
#                                                                       '#B72F15',
#                                                                       '#D6610A',
#                                                                       '#EF9100',
#                                                                       '#FFC300'],
#                                                            'name': 'Global '
#                                                                    'Warming',
#                                                            'type': 'sequential'},
#                                       'thickness': 2}},
#              'id': 'ih1xeqf',
#              'type': 'point',
#              'visualChannels': {'colorField': {'name': 'Math_avg_score',
#                                                'type': 'real'},
#                                 'colorScale': 'quantile',
#                                 'sizeField': {'name': 'Math_avg_score',
#                                               'type': 'real'},
#                                 'sizeScale': 'sqrt',
#                                 'strokeColorField': None,
#                                 'strokeColorScale': 'quantile'}},
#             {'config': {'color': [179, 173, 158],
#                         'columnMode': 'points',
#                         'columns': {'lat': 'lat', 'lng': 'lon'},
#                         'dataId': 'b75b865b-454e-42c7-b27e-8a0493754aba',
#                         'hidden': False,
#                         'isVisible': False,
#                         'label': 'Google_rating',
#                         'textLabel': [{'alignment': 'center',
#                                        'anchor': 'start',
#                                        'color': [255, 255, 255],
#                                        'field': [],
#                                        'offset': [0, 0],
#                                        'size': 18}],
#                         'visConfig': {'allowHover': True,
#                                       'billboard': False,
#                                       'colorRange': {'category': 'Custom',
#                                                      'colorMap': [[2,
#                                                                    '#A50026'],
#                                                                   [3,
#                                                                    '#F88D52'],
#                                                                   [4,
#                                                                    '#FAF8C1'],
#                                                                   [4.5,
#                                                                    '#90C2DD'],
#                                                                   [5,
#                                                                    '#313695'],
#                                                                   [None,
#                                                                    '#313695']],
#                                                      'colors': ['#A50026',
#                                                                 '#F88D52',
#                                                                 '#FAF8C1',
#                                                                 '#90C2DD',
#                                                                 '#313695',
#                                                                 '#313695'],
#                                                      'name': 'color.customPalette',
#                                                      'type': 'custom'},
#                                       'filled': True,
#                                       'fixedRadius': False,
#                                       'opacity': 0.5,
#                                       'outline': False,
#                                       'radius': 10,
#                                       'radiusRange': [0, 20],
#                                       'showHighlightColor': True,
#                                       'showNeighborOnHover': False,
#                                       'strokeColor': None,
#                                       'strokeColorRange': {'category': 'Uber',
#                                                            'colors': ['#4C0035',
#                                                                       '#880030',
#                                                                       '#B72F15',
#                                                                       '#D6610A',
#                                                                       '#EF9100',
#                                                                       '#FFC300'],
#                                                            'name': 'Global '
#                                                                    'Warming',
#                                                            'type': 'sequential'},
#                                       'thickness': 2}},
#              'id': 'b6gh5qn',
#              'type': 'point',
#              'visualChannels': {'colorField': {'name': 'Google_rating',
#                                                'type': 'real'},
#                                 'colorScale': 'custom',
#                                 'sizeField': {'name': 'Google_rating',
#                                               'type': 'real'},
#                                 'sizeScale': 'sqrt',
#                                 'strokeColorField': None,
#                                 'strokeColorScale': 'quantile'}},
#             {'config': {'color': [179, 173, 158],
#                         'columnMode': 'points',
#                         'columns': {'lat': 'lat', 'lng': 'lon'},
#                         'dataId': 'b75b865b-454e-42c7-b27e-8a0493754aba',
#                         'hidden': False,
#                         'isVisible': True,
#                         'label': 'grand_average',
#                         'textLabel': [{'alignment': 'center',
#                                        'anchor': 'start',
#                                        'color': [255, 255, 255],
#                                        'field': [],
#                                        'offset': [0, 0],
#                                        'size': 18}],
#                         'visConfig': {'allowHover': True,
#                                       'billboard': False,
#                                       'colorRange': {'category': 'ColorBrewer',
#                                                      'colors': ['#A50026',
#                                                                 '#F88D52',
#                                                                 '#FAF8C1',
#                                                                 '#90C2DD',
#                                                                 '#313695'],
#                                                      'name': 'RdYlBu',
#                                                      'type': 'diverging'},
#                                       'filled': True,
#                                       'fixedRadius': False,
#                                       'opacity': 0.5,
#                                       'outline': False,
#                                       'radius': 10,
#                                       'radiusRange': [5, 50],
#                                       'showHighlightColor': True,
#                                       'showNeighborOnHover': False,
#                                       'strokeColor': None,
#                                       'strokeColorRange': {'category': 'Uber',
#                                                            'colors': ['#4C0035',
#                                                                       '#880030',
#                                                                       '#B72F15',
#                                                                       '#D6610A',
#                                                                       '#EF9100',
#                                                                       '#FFC300'],
#                                                            'name': 'Global '
#                                                                    'Warming',
#                                                            'type': 'sequential'},
#                                       'thickness': 2}},
#              'id': 'pijyjo',
#              'type': 'point',
#              'visualChannels': {'colorField': {'name': 'grand_avg_score',
#                                                'type': 'real'},
#                                 'colorScale': 'quantile',
#                                 'sizeField': {'name': 'Google_rating',
#                                               'type': 'real'},
#                                 'sizeScale': 'sqrt',
#                                 'strokeColorField': None,
#                                 'strokeColorScale': 'quantile'}}],
#  'metrics': [],
#  'overlayBlending': 'normal',
#  'splitMaps': []}

# %% [markdown]
# # Ranking

# %%
cols =  ['SKOLENHETENS NAMN', 'HUVUDMANNATYP', 'KOMMUNNAMN', 'Google_rating'] + avg_df.columns[avg_df.columns.str.endswith('score')].to_list()

avg_df[cols].sort_values('grand_avg_score', ascending=False).reset_index(drop=True).head(20)
# Out:
#                          SKOLENHETENS NAMN HUVUDMANNATYP  KOMMUNNAMN  \
# 0                       Vendestigens skola       Enskild    Danderyd
# 1           Montessori Mondial Kungsholmen       Enskild   Stockholm
# 2              Musikskolan Lilla Akademien       Enskild   Stockholm
# 3                Fredrikshovs slotts skola       Enskild   Stockholm
# 4              Adolf Fredriks musikklasser      Kommunal   Stockholm
# 5                  Sollentuna musikklasser      Kommunal  Sollentuna
# 6                          Carlssons skola       Enskild   Stockholm
# 7               Innovitaskolan Banérporten       Enskild   Stockholm
# 8                             Hillelskolan       Enskild   Stockholm
# 9                            Ytterbyskolan      Kommunal        Täby
# 10                        Enebybergs skola      Kommunal    Danderyd
# 11                        Östermalmsskolan      Kommunal   Stockholm
# 12  Internationella Engelska Skolan Bromma       Enskild   Stockholm
# 13             Kunskapsskolan Saltsjöbaden       Enskild       Nacka
# 14                          Johannes skola      Kommunal   Stockholm
# 15              Spirande lärande i Täby AB       Enskild        Täby
# 16                             Ekebyskolan      Kommunal    Danderyd
# 17                        Stocksundsskolan      Kommunal    Danderyd
# 18                         Äppelviksskolan      Kommunal   Stockholm
# 19   Internationella Engelska Skolan Nacka       Enskild       Nacka
#
#     Google_rating  English_avg_score  Math_avg_score  Swedish_avg_score  \
# 0             2.3          17.725000       17.000000          18.900000
# 1             3.4          19.233333       16.766667          16.475000
# 2             3.6          17.925000       17.066667          16.958333
# 3             4.0          19.000000       16.733333          16.108333
# 4             4.0          18.350000       16.066667          16.866667
# 5             3.3          18.350000       16.166667          16.591667
# 6             4.3          18.141667       16.733333          16.200000
# 7             4.2          17.683333       16.800000          16.558333
# 8             NaN          18.133333       16.200000          16.466667
# 9             4.3          18.125000       16.000000          16.575000
# 10            4.1          17.416667       17.166667          16.058333
# 11            3.3          17.866667       16.600000          16.075000
# 12            4.0          18.841667       14.633333          16.975000
# 13            4.0          18.016667       15.166667          16.916667
# 14            3.0          19.108333       16.666667          16.141667
# 15            NaN          18.016667       14.700000          17.175000
# 16            4.5          17.812500       16.450000          15.587500
# 17            2.4          17.333333       16.666667          15.575000
# 18            4.0          17.475000       15.900000          16.183333
# 19            3.5          19.091667       15.433333          14.983333
#
#     Swedish_as_a_second_language_avg_score  grand_avg_score
# 0                                      NaN        17.875000
# 1                                      NaN        17.491667
# 2                                      NaN        17.316667
# 3                                      NaN        17.280556
# 4                                      NaN        17.094444
# 5                                      NaN        17.036111
# 6                                      NaN        17.025000
# 7                                      NaN        17.013889
# 8                                      NaN        16.933333
# 9                                      NaN        16.900000
# 10                                     NaN        16.880556
# 11                                     NaN        16.847222
# 12                                     NaN        16.816667
# 13                                     NaN        16.700000
# 14                                   14.65        16.641667
# 15                                     NaN        16.630556
# 16                                     NaN        16.616667
# 17                                     NaN        16.525000
# 18                                     NaN        16.519444
# 19                                     NaN        16.502778

# %%
avg_df[avg_df['SKOLENHETENS NAMN'].str.contains('Innovita')][cols].sort_values('grand_avg_score', ascending=False).reset_index(drop=True).head(20)
# Out:
#                       SKOLENHETENS NAMN HUVUDMANNATYP  KOMMUNNAMN  \
# 0            Innovitaskolan Banérporten       Enskild   Stockholm
# 1              Innovitaskolan Södermalm       Enskild   Stockholm
# 2              Innovitaskolan Norrtälje       Enskild   Norrtälje
# 3             Innovitaskolan Södertälje       Enskild  Södertälje
# 4               Innovitaskolan Vendelsö       Enskild     Haninge
# 5                  Innovitaskolan Rudan       Enskild     Haninge
# 6  Innovitaskolan Södermalms Högstadium       Enskild   Stockholm
#
#    Google_rating  English_avg_score  Math_avg_score  Swedish_avg_score  \
# 0            4.2          17.683333       16.800000          16.558333
# 1            2.6          16.033333       13.500000          14.983333
# 2            4.0          14.683333       11.800000          14.075000
# 3            4.8          14.175000       12.366667          13.666667
# 4            3.2          13.525000       11.700000          12.962500
# 5            3.4          15.291667        9.766667          12.450000
# 6            2.6          14.175000        8.833333          12.308333
#
#    Swedish_as_a_second_language_avg_score  grand_avg_score
# 0                                     NaN        17.013889
# 1                                     NaN        14.838889
# 2                                     NaN        13.519444
# 3                                  13.325        13.383333
# 4                                     NaN        12.729167
# 5                                     NaN        12.502778
# 6                                     NaN        11.772222

# %% [markdown]
# # Download [income statistics](https://www.statistikdatabasen.scb.se/pxweb/en/ssd/START__HE__HE0110__HE0110I/Tab1InkDesoN/)
#
# - [DeSo query](https://www.statistikdatabasen.scb.se/sq/126773)
# - [RegSO query](https://www.statistikdatabasen.scb.se/sq/126774)

# %%
deso = pd.read_excel('data/DeSo.xlsx',
                    header=[2],
                    index_col=[0,1,2,3])

deso.head(10)
# Out:
#                                            Median value, SEK thousands  \
#  0114A0010 total earned income total 2018                        327.4
#                                      2019                        334.6
#                                      2020                        338.1
#            net income          total 2018                        278.1
#                                      2019                        281.9
#                                      2020                        279.3
#  0114C1010 total earned income total 2018                        392.0
#                                      2019                        391.7
#                                      2020                        406.8
#            net income          total 2018                        322.7
#
#                                           Mean value, SEK thousands  \
#  0114A0010 total earned income total 2018                     380.4
#                                      2019                     382.6
#                                      2020                     380.5
#            net income          total 2018                     651.5
#                                      2019                     547.9
#                                      2020                     460.5
#  0114C1010 total earned income total 2018                       448
#                                      2019                     460.7
#                                      2020                     458.1
#            net income          total 2018                     397.5
#
#                                            Number of persons
#  0114A0010 total earned income total 2018              610.0
#                                      2019              605.0
#                                      2020              605.0
#            net income          total 2018              610.0
#                                      2019              605.0
#                                      2020              605.0
#  0114C1010 total earned income total 2018             1111.0
#                                      2019             1130.0
#                                      2020             1137.0
#            net income          total 2018             1111.0

# %%
deso = deso.reset_index().dropna(subset=['Median value, SEK thousands'])
deso = deso.drop(columns=['level_2'])
deso = deso.rename(columns= {
    'level_0': 'deso',
    'level_1': 'income_type',
    'level_3': 'year',
    'Median value, SEK thousands': 'median_kSEK',
    'Mean value, SEK thousands': 'mean_kSEK',
    'Number of persons': 'num_persons'
})

deso['deso'] = deso['deso'].apply(lambda x:x.strip())
deso['mean_kSEK'] = deso['mean_kSEK'].replace('..', np.nan).astype(float)
deso.head(10)
# Out:
#         deso          income_type  year  median_kSEK  mean_kSEK  num_persons
# 0  0114A0010  total earned income  2018        327.4      380.4        610.0
# 1  0114A0010  total earned income  2019        334.6      382.6        605.0
# 2  0114A0010  total earned income  2020        338.1      380.5        605.0
# 3  0114A0010           net income  2018        278.1      651.5        610.0
# 4  0114A0010           net income  2019        281.9      547.9        605.0
# 5  0114A0010           net income  2020        279.3      460.5        605.0
# 6  0114C1010  total earned income  2018        392.0      448.0       1111.0
# 7  0114C1010  total earned income  2019        391.7      460.7       1130.0
# 8  0114C1010  total earned income  2020        406.8      458.1       1137.0
# 9  0114C1010           net income  2018        322.7      397.5       1111.0

# %%
regso = pd.read_excel('data/RegSO.xlsx',
                    header=[2],
                    index_col=[0,1,2,3])

regso.head(10)
# Out:
#                                                                   Median value, SEK thousands  \
# Upplands Väsby (Bollstanäs)       total earned income total 2018                        395.3
#                                                             2019                        396.4
#                                                             2020                        401.9
#                                   net income          total 2018                        323.9
#                                                             2019                        327.0
#                                                             2020                        332.7
# Upplands Väsby (Hammarby-Vaxmyra) total earned income total 2018                        312.8
#                                                             2019                        315.9
#                                                             2020                        321.6
#                                   net income          total 2018                        255.1
#
#                                                                  Mean value, SEK thousands  \
# Upplands Väsby (Bollstanäs)       total earned income total 2018                     444.3
#                                                             2019                     448.9
#                                                             2020                     453.5
#                                   net income          total 2018                     382.3
#                                                             2019                     367.7
#                                                             2020                     372.4
# Upplands Väsby (Hammarby-Vaxmyra) total earned income total 2018                       335
#                                                             2019                     360.1
#                                                             2020                     371.6
#                                   net income          total 2018                     421.4
#
#                                                                   Number of persons
# Upplands Väsby (Bollstanäs)       total earned income total 2018             4200.0
#                                                             2019             4218.0
#                                                             2020             4209.0
#                                   net income          total 2018             4200.0
#                                                             2019             4218.0
#                                                             2020             4209.0
# Upplands Väsby (Hammarby-Vaxmyra) total earned income total 2018             1943.0
#                                                             2019             1955.0
#                                                             2020             1910.0
#                                   net income          total 2018             1943.0

# %%
regso = regso.reset_index().dropna(subset=['Median value, SEK thousands'])
regso = regso.drop(columns=['level_2'])
regso = regso.rename(columns= {
    'level_0': 'regso',
    'level_1': 'income_type',
    'level_3': 'year',
    'Median value, SEK thousands': 'median_kSEK',
    'Mean value, SEK thousands': 'mean_kSEK',
    'Number of persons': 'num_persons'
})

regso['regso'] = regso['regso'].apply(lambda x:x.strip())
regso.head(10)
# Out:
#                                regso          income_type  year  median_kSEK  \
# 0        Upplands Väsby (Bollstanäs)  total earned income  2018        395.3
# 1        Upplands Väsby (Bollstanäs)  total earned income  2019        396.4
# 2        Upplands Väsby (Bollstanäs)  total earned income  2020        401.9
# 3        Upplands Väsby (Bollstanäs)           net income  2018        323.9
# 4        Upplands Väsby (Bollstanäs)           net income  2019        327.0
# 5        Upplands Väsby (Bollstanäs)           net income  2020        332.7
# 6  Upplands Väsby (Hammarby-Vaxmyra)  total earned income  2018        312.8
# 7  Upplands Väsby (Hammarby-Vaxmyra)  total earned income  2019        315.9
# 8  Upplands Väsby (Hammarby-Vaxmyra)  total earned income  2020        321.6
# 9  Upplands Väsby (Hammarby-Vaxmyra)           net income  2018        255.1
#
#   mean_kSEK  num_persons
# 0     444.3       4200.0
# 1     448.9       4218.0
# 2     453.5       4209.0
# 3     382.3       4200.0
# 4     367.7       4218.0
# 5     372.4       4209.0
# 6       335       1943.0
# 7     360.1       1955.0
# 8     371.6       1910.0
# 9     421.4       1943.0

# %% [markdown]
# # Download [DeSO geometry](https://www.scb.se/vara-tjanster/oppna-data/oppna-geodata/deso--demografiska-statistikomraden/) and [RegSO geometry](https://www.scb.se/vara-tjanster/oppna-data/oppna-geodata/regso/)
#
# - Polygons are represented in the EPSG:3006 (SWEREF99 TM) reference system

# %%
import geopandas as gpd

deso_gdf = gpd.read_file('data/large_files/DeSO_2018_v2.gpkg', geometry='geometry', crs='EPSG:3006')
deso_gdf = deso_gdf.to_crs('EPSG:4326')
deso_gdf.head()
# Out:
#                                      uuid       deso kommun lan    kommunnamn  \
# 0  {8DE2583C-6A92-45B5-AD41-7F40B7A90862}  1256B2010   1256  12  Östra Göinge
# 1  {5D108A83-8951-4345-A942-80D6F4E2D1A3}  0760B3010   0760  07    Uppvidinge
# 2  {FEA0F678-ED55-4CFC-8CF9-92C0050D102C}  1082C1120   1082  10     Karlshamn
# 3  {5AF0864D-40F8-4599-8AA6-636D82976DB3}  1292A0010   1292  12     Ängelholm
# 4  {3FA12A3D-7B03-40BE-8633-4F8951101882}  1081C1070   1081  10       Ronneby
#
#      lannamn  version                                           geometry
# 0      Skåne  2018_v2  POLYGON ((14.07133 56.20739, 14.07044 56.20703...
# 1  Kronoberg  2018_v2  POLYGON ((15.19121 57.11992, 15.19121 57.11958...
# 2   Blekinge  2018_v2  POLYGON ((14.85263 56.20908, 14.85245 56.20876...
# 3      Skåne  2018_v2  POLYGON ((12.78956 56.20266, 12.79193 56.20137...
# 4   Blekinge  2018_v2  POLYGON ((15.27983 56.22239, 15.27982 56.22231...

# %%
deso_gdf.plot()
# Out:
# <AxesSubplot:>

# %%
regso_gdf = gpd.read_file('data/large_files/RegSO_2018_v1.gpkg', geometry='geometry', crs='EPSG:3006')
regso_gdf = regso_gdf.to_crs('EPSG:4326')
regso_gdf.head()
# Out:
#                                    uuid  regsokod  \
# 0  C719D86A-F497-4C24-9556-6F2EEC713C16  2482R010
# 1  FD0A06B6-52F9-415C-9264-FC06908B54F2  1862R001
# 2  12C701A2-1F2A-418B-BD37-75BA6F3F5E79  1763R001
# 3  D6931531-C051-4A6E-AE70-991FFCA0D655  1281R006
# 4  90E1D12D-E192-475B-BF0E-3EDFAE3C45DA  2184R003
#
#                      kommunregso                     regso kommun  kommunnamn  \
# 0      2482 Degerbyn-Prästbordet      Degerbyn-Prästbordet   2482  Skellefteå
# 1  1862 Degerfors centrum-Bruket  Degerfors centrum-Bruket   1862   Degerfors
# 2             1763 Deje-Dejefors             Deje-Dejefors   1763    Forshaga
# 3    1281 Delphinen-Kämnärsvägen    Delphinen-Kämnärsvägen   1281        Lund
# 4                    2184 Delsbo                    Delsbo   2184  Hudiksvall
#
#    version                                           geometry
# 0  2018_v1  POLYGON ((20.94616 64.75441, 20.94616 64.75441...
# 1  2018_v1  POLYGON ((14.46880 59.24573, 14.46880 59.24572...
# 2  2018_v1  POLYGON ((13.51818 59.59721, 13.51820 59.59686...
# 3  2018_v1  POLYGON ((13.22493 55.72304, 13.22282 55.71941...
# 4  2018_v1  POLYGON ((16.64062 61.78314, 16.64060 61.78280...

# %%
regso_gdf.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Merge income stat and geometry

# %%
deso_with_geo = deso.merge(deso_gdf[['deso','kommunnamn', 'lannamn', 'geometry']], on='deso')
deso_with_geo.head()
# Out:
#         deso          income_type  year  median_kSEK  mean_kSEK  num_persons  \
# 0  0114A0010  total earned income  2018        327.4      380.4        610.0
# 1  0114A0010  total earned income  2019        334.6      382.6        605.0
# 2  0114A0010  total earned income  2020        338.1      380.5        605.0
# 3  0114A0010           net income  2018        278.1      651.5        610.0
# 4  0114A0010           net income  2019        281.9      547.9        605.0
#
#        kommunnamn    lannamn  \
# 0  Upplands Väsby  Stockholm
# 1  Upplands Väsby  Stockholm
# 2  Upplands Väsby  Stockholm
# 3  Upplands Väsby  Stockholm
# 4  Upplands Väsby  Stockholm
#
#                                             geometry
# 0  POLYGON ((17.85191 59.56670, 17.85288 59.56658...
# 1  POLYGON ((17.85191 59.56670, 17.85288 59.56658...
# 2  POLYGON ((17.85191 59.56670, 17.85288 59.56658...
# 3  POLYGON ((17.85191 59.56670, 17.85288 59.56658...
# 4  POLYGON ((17.85191 59.56670, 17.85288 59.56658...

# %%
deso_with_geo.shape, deso.shape
# Out:
# ((35904, 9), (35904, 6))

# %%
tmp = deso_with_geo.query('income_type == "total earned income"').groupby('deso')['median_kSEK'].mean().reset_index()
deso_plot = tmp.merge(deso_gdf[['deso','kommunnamn', 'lannamn', 'geometry']], on='deso')
deso_plot.head()
# Out:
#         deso  median_kSEK      kommunnamn    lannamn  \
# 0  0114A0010   333.366667  Upplands Väsby  Stockholm
# 1  0114C1010   396.833333  Upplands Väsby  Stockholm
# 2  0114C1020   382.566667  Upplands Väsby  Stockholm
# 3  0114C1030   366.833333  Upplands Väsby  Stockholm
# 4  0114C1040   293.100000  Upplands Väsby  Stockholm
#
#                                             geometry
# 0  POLYGON ((17.85191 59.56670, 17.85288 59.56658...
# 1  POLYGON ((17.94907 59.49432, 17.94926 59.49423...
# 2  POLYGON ((17.92041 59.49623, 17.92041 59.49623...
# 3  POLYGON ((17.95169 59.49699, 17.95167 59.49689...
# 4  POLYGON ((17.90827 59.51431, 17.90926 59.51429...

# %%
from uuid import uuid4
from unfolded.map_sdk import UnfoldedMap

income_map = UnfoldedMap(width='100%', height='90vh')

income_map
# Out:
# UnfoldedMap(height='90vh')

# %%
dataset_id = uuid4()
income_map.add_dataset({
    'uuid': dataset_id,
    'label': 'DeSO',
    'data': deso_plot,
    },
    auto_create_layers=False)
# Out:
# <Future pending>

# %% [markdown]
# # Income adjustment

# %%
import pandas as pd
import geopandas as gpd

avg_df = pd.read_csv('data/avg_df.csv')

deso_gdf = gpd.read_file('data/large_files/DeSO_2018_v2.gpkg', geometry='geometry', crs='EPSG:3006')
deso_gdf = deso_gdf.to_crs('EPSG:4326')

deso = pd.read_excel('data/DeSo.xlsx',
                    header=[2],
                    index_col=[0,1,2,3])
deso = deso.reset_index().dropna(subset=['Median value, SEK thousands'])
deso = deso.drop(columns=['level_2'])
deso = deso.rename(columns= {
    'level_0': 'deso',
    'level_1': 'income_type',
    'level_3': 'year',
    'Median value, SEK thousands': 'median_kSEK',
    'Mean value, SEK thousands': 'mean_kSEK',
    'Number of persons': 'num_persons'
})
deso['deso'] = deso['deso'].apply(lambda x:x.strip())
deso['mean_kSEK'] = deso['mean_kSEK'].replace('..', np.nan).astype(float)

deso_with_geo = deso.merge(deso_gdf[['deso','kommunnamn', 'lannamn', 'geometry']], on='deso')

# %%
avg_df.head()
# Out:
#    SKOLENHETSKOD  English_avg_score  Math_avg_score  Swedish_avg_score  \
# 0       10063280          14.125000        9.833333          12.308333
# 1       10225038          15.550000       14.133333          12.983333
# 2       10360193          15.550000       12.600000          15.700000
# 3       10661388          11.883333       10.166667          14.191667
# 4       10715898          16.333333       13.200000          14.900000
#
#    Swedish_as_a_second_language_avg_score  grand_avg_score HUVUDMANNATYP  \
# 0                                     NaN        12.088889       Enskild
# 1                                     NaN        14.222222      Kommunal
# 2                                     NaN        14.616667       Enskild
# 3                                     NaN        12.080556       Enskild
# 4                                     NaN        14.811111       Enskild
#
#    KOMMUNNAMN  SKOLENHETENS NAMN           BESÖKSADRESS  BESÖKSPOSTNR  \
# 0    Huddinge        Skapaskolan       Midsommarvägen 4         14144
# 1    Huddinge     Solfagraskolan       Prästvägen 23-25         14131
# 2   Stockholm       Profilskolan  Krossgatan 34, plan 4         16250
# 3  Södertälje  Örjanskolan grund                 Nibble         15391
# 4   Österåker     Akers Friskola           Svampvägen 4         18438
#
#   BESÖKSPOSTORT                                   WEBB FKLASS        lon  \
# 0      Huddinge              http://www.skapaskolan.se      J  17.960402
# 1      Huddinge  http://www.huddinge.se/solfagraskolan      J  18.009328
# 2     Vällingby             http://www.profilskolan.se      J  17.856736
# 3         Järna              http://www.orjanskolan.se      J  17.616505
# 4    Åkersberga            http://www.akersfriskola.se      J  18.332378
#
#          lat  Google_rating
# 0  59.233668            2.4
# 1  59.239366            3.8
# 2  59.372352            3.5
# 3  59.066291            3.8
# 4  59.491625            4.0

# %%
deso_with_geo.head()
# Out:
#         deso          income_type  year  median_kSEK  mean_kSEK  num_persons  \
# 0  0114A0010  total earned income  2018        327.4      380.4        610.0
# 1  0114A0010  total earned income  2019        334.6      382.6        605.0
# 2  0114A0010  total earned income  2020        338.1      380.5        605.0
# 3  0114A0010           net income  2018        278.1      651.5        610.0
# 4  0114A0010           net income  2019        281.9      547.9        605.0
#
#        kommunnamn    lannamn  \
# 0  Upplands Väsby  Stockholm
# 1  Upplands Väsby  Stockholm
# 2  Upplands Väsby  Stockholm
# 3  Upplands Väsby  Stockholm
# 4  Upplands Väsby  Stockholm
#
#                                             geometry
# 0  POLYGON ((17.85191 59.56670, 17.85288 59.56658...
# 1  POLYGON ((17.85191 59.56670, 17.85288 59.56658...
# 2  POLYGON ((17.85191 59.56670, 17.85288 59.56658...
# 3  POLYGON ((17.85191 59.56670, 17.85288 59.56658...
# 4  POLYGON ((17.85191 59.56670, 17.85288 59.56658...

# %%
from shapely.geometry import Point

avg_df['point'] = avg_df[['lon', 'lat']].apply(lambda v:Point(v[0], v[1]), axis=1)
avg_df.head()
# Out:
# /opt/conda/lib/python3.10/site-packages/pandas/core/dtypes/cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#    SKOLENHETSKOD  English_avg_score  Math_avg_score  Swedish_avg_score  \
# 0       10063280          14.125000        9.833333          12.308333
# 1       10225038          15.550000       14.133333          12.983333
# 2       10360193          15.550000       12.600000          15.700000
# 3       10661388          11.883333       10.166667          14.191667
# 4       10715898          16.333333       13.200000          14.900000
#
#    Swedish_as_a_second_language_avg_score  grand_avg_score HUVUDMANNATYP  \
# 0                                     NaN        12.088889       Enskild
# 1                                     NaN        14.222222      Kommunal
# 2                                     NaN        14.616667       Enskild
# 3                                     NaN        12.080556       Enskild
# 4                                     NaN        14.811111       Enskild
#
#    KOMMUNNAMN  SKOLENHETENS NAMN           BESÖKSADRESS  BESÖKSPOSTNR  \
# 0    Huddinge        Skapaskolan       Midsommarvägen 4         14144
# 1    Huddinge     Solfagraskolan       Prästvägen 23-25         14131
# 2   Stockholm       Profilskolan  Krossgatan 34, plan 4         16250
# 3  Södertälje  Örjanskolan grund                 Nibble         15391
# 4   Österåker     Akers Friskola           Svampvägen 4         18438
#
#   BESÖKSPOSTORT                                   WEBB FKLASS        lon  \
# 0      Huddinge              http://www.skapaskolan.se      J  17.960402
# 1      Huddinge  http://www.huddinge.se/solfagraskolan      J  18.009328
# 2     Vällingby             http://www.profilskolan.se      J  17.856736
# 3         Järna              http://www.orjanskolan.se      J  17.616505
# 4    Åkersberga            http://www.akersfriskola.se      J  18.332378
#
#          lat  Google_rating                                 point
# 0  59.233668            2.4         POINT (17.9604016 59.2336677)
# 1  59.239366            3.8  POINT (18.0093278 59.23936579999999)
# 2  59.372352            3.5  POINT (17.8567362 59.37235159999999)
# 3  59.066291            3.8         POINT (17.6165051 59.0662909)
# 4  59.491625            4.0         POINT (18.3323781 59.4916248)

# %%
from tqdm import tqdm

deso_geo = deso_with_geo[['deso', 'geometry']].drop_duplicates(subset='deso').reset_index(drop=True)
deso_geo = gpd.GeoDataFrame(deso_geo, geometry='geometry', crs='EPSG:4326').to_crs('EPSG:32633')

school_df = avg_df[['SKOLENHETSKOD', 'lon', 'lat']]
school_df['point'] = school_df[['lon', 'lat']].apply(lambda v:Point(v[0], v[1]), axis=1)
school_df = gpd.GeoDataFrame(school_df, geometry='point', crs='EPSG:4326')
school_df = school_df.to_crs('EPSG:32633')

TH = 1000

def neighbouring_deso(school_df, deso_geo):
    result_dict = {}
    for i, row in tqdm(school_df.iterrows(), total=len(school_df)):
        mask = deso_geo.distance(row['point']) <= TH
        result_dict[row['SKOLENHETSKOD']] = deso_geo[mask]['deso'].values
    return result_dict

school_deso = neighbouring_deso(school_df, deso_geo)
# Out:
# /opt/conda/lib/python3.10/site-packages/pandas/core/dtypes/cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# /tmp/ipykernel_465/939585106.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   school_df['point'] = school_df[['lon', 'lat']].apply(lambda v:Point(v[0], v[1]), axis=1)
# 100%|██████████| 494/494 [01:02<00:00,  7.88it/s]

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots()

id_ = 10715898

deso_geo.query(f'deso in @school_deso[{id_}]').plot(ax=axes)
school_df.query(f'SKOLENHETSKOD == {id_}').plot(ax=axes, c='yellow')
# Out:
# <AxesSubplot:>

# %%
deso_income = deso_with_geo[['deso', 'median_kSEK']].drop_duplicates(subset='deso').reset_index(drop=True)

def avg_income(school_deso, deso_income):
    result_dict = {}
    for k, desos in school_deso.items():
        result_dict[k] = deso_income.query('deso in @desos')['median_kSEK'].mean()
    return result_dict

school_income = avg_income(school_deso, deso_income)

# %%
school_income_df = pd.DataFrame.from_dict(school_income, orient='index').reset_index().rename(columns={'index':'SKOLENHETSKOD', 0:'median_kSEK'})
school_income_df.head()
# Out:
#    SKOLENHETSKOD  median_kSEK
# 0       10063280   330.330000
# 1       10225038   359.533333
# 2       10360193   308.264706
# 3       10661388   325.000000
# 4       10715898   341.760000

# %%
school_summary = avg_df.merge(school_income_df, on='SKOLENHETSKOD')
school_summary.head()
# Out:
#    SKOLENHETSKOD  English_avg_score  Math_avg_score  Swedish_avg_score  \
# 0       10063280          14.125000        9.833333          12.308333
# 1       10225038          15.550000       14.133333          12.983333
# 2       10360193          15.550000       12.600000          15.700000
# 3       10661388          11.883333       10.166667          14.191667
# 4       10715898          16.333333       13.200000          14.900000
#
#    Swedish_as_a_second_language_avg_score  grand_avg_score HUVUDMANNATYP  \
# 0                                     NaN        12.088889       Enskild
# 1                                     NaN        14.222222      Kommunal
# 2                                     NaN        14.616667       Enskild
# 3                                     NaN        12.080556       Enskild
# 4                                     NaN        14.811111       Enskild
#
#    KOMMUNNAMN  SKOLENHETENS NAMN           BESÖKSADRESS  BESÖKSPOSTNR  \
# 0    Huddinge        Skapaskolan       Midsommarvägen 4         14144
# 1    Huddinge     Solfagraskolan       Prästvägen 23-25         14131
# 2   Stockholm       Profilskolan  Krossgatan 34, plan 4         16250
# 3  Södertälje  Örjanskolan grund                 Nibble         15391
# 4   Österåker     Akers Friskola           Svampvägen 4         18438
#
#   BESÖKSPOSTORT                                   WEBB FKLASS        lon  \
# 0      Huddinge              http://www.skapaskolan.se      J  17.960402
# 1      Huddinge  http://www.huddinge.se/solfagraskolan      J  18.009328
# 2     Vällingby             http://www.profilskolan.se      J  17.856736
# 3         Järna              http://www.orjanskolan.se      J  17.616505
# 4    Åkersberga            http://www.akersfriskola.se      J  18.332378
#
#          lat  Google_rating                                 point  median_kSEK
# 0  59.233668            2.4         POINT (17.9604016 59.2336677)   330.330000
# 1  59.239366            3.8  POINT (18.0093278 59.23936579999999)   359.533333
# 2  59.372352            3.5  POINT (17.8567362 59.37235159999999)   308.264706
# 3  59.066291            3.8         POINT (17.6165051 59.0662909)   325.000000
# 4  59.491625            4.0         POINT (18.3323781 59.4916248)   341.760000

# %%
X = pd.get_dummies(school_summary['SKOLENHETSKOD'])
X = np.concatenate((school_summary['median_kSEK'].values.reshape(-1, 1), X), axis=1)
X.shape
# Out:
# (494, 495)

# %%
y = school_summary['grand_avg_score'].values.reshape(-1, 1)
y.shape
# Out:
# (494, 1)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler

reg = LinearRegression().fit(X, y)

# %%
reg.intercept_
# Out:
# array([5.37021706])

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, r2_score

y_linear = reg.intercept_ + reg.coef_[:,0]*X[:,0]

plt.scatter(X[:,0], y, color='black', s=2)
plt.plot(X[:,0], y_linear, color='blue')

print("Mean squared error: %.2f" % mean_squared_error(y, y_linear))
print("Coefficient of determination: %.2f" % r2_score(y, y_linear))
# Out:
# Mean squared error: 2.28
# Coefficient of determination: 0.42

# %%
import matplotlib.pyplot as plt

residual = y.flatten() - (reg.intercept_ + reg.coef_[:,0]*X[:,0])

pos = residual[residual >= 0]
neg = residual[residual < 0]

plt.scatter(X[residual >= 0,0], pos, color='blue', s=2)
plt.scatter(X[residual < 0,0], neg, color='red', s=2)

# %%
school_summary['residual'] = residual
school_summary.head()
# Out:
#    SKOLENHETSKOD  English_avg_score  Math_avg_score  Swedish_avg_score  \
# 0       10063280          14.125000        9.833333          12.308333
# 1       10225038          15.550000       14.133333          12.983333
# 2       10360193          15.550000       12.600000          15.700000
# 3       10661388          11.883333       10.166667          14.191667
# 4       10715898          16.333333       13.200000          14.900000
#
#    Swedish_as_a_second_language_avg_score  grand_avg_score HUVUDMANNATYP  \
# 0                                     NaN        12.088889       Enskild
# 1                                     NaN        14.222222      Kommunal
# 2                                     NaN        14.616667       Enskild
# 3                                     NaN        12.080556       Enskild
# 4                                     NaN        14.811111       Enskild
#
#    KOMMUNNAMN  SKOLENHETENS NAMN           BESÖKSADRESS  BESÖKSPOSTNR  \
# 0    Huddinge        Skapaskolan       Midsommarvägen 4         14144
# 1    Huddinge     Solfagraskolan       Prästvägen 23-25         14131
# 2   Stockholm       Profilskolan  Krossgatan 34, plan 4         16250
# 3  Södertälje  Örjanskolan grund                 Nibble         15391
# 4   Österåker     Akers Friskola           Svampvägen 4         18438
#
#   BESÖKSPOSTORT                                   WEBB FKLASS        lon  \
# 0      Huddinge              http://www.skapaskolan.se      J  17.960402
# 1      Huddinge  http://www.huddinge.se/solfagraskolan      J  18.009328
# 2     Vällingby             http://www.profilskolan.se      J  17.856736
# 3         Järna              http://www.orjanskolan.se      J  17.616505
# 4    Åkersberga            http://www.akersfriskola.se      J  18.332378
#
#          lat  Google_rating                                 point  \
# 0  59.233668            2.4         POINT (17.9604016 59.2336677)
# 1  59.239366            3.8  POINT (18.0093278 59.23936579999999)
# 2  59.372352            3.5  POINT (17.8567362 59.37235159999999)
# 3  59.066291            3.8         POINT (17.6165051 59.0662909)
# 4  59.491625            4.0         POINT (18.3323781 59.4916248)
#
#    median_kSEK  residual
# 0   330.330000 -1.173974
# 1   359.533333  0.261598
# 2   308.264706  1.881014
# 3   325.000000 -1.054957
# 4   341.760000  1.275149

# %%
school_summary['residual'].describe()
# Out:
# count    4.940000e+02
# mean    -4.385156e-15
# std      1.510418e+00
# min     -9.679838e+00
# 25%     -8.654860e-01
# 50%      6.280772e-02
# 75%      9.984133e-01
# max      3.316464e+00
# Name: residual, dtype: float64

# %%
school_summary.to_csv('data/school_summary.csv')

# %%
plt.scatter(school_summary['grand_avg_score'], school_summary['Google_rating'], color='black', s=2)

# %%
plt.scatter(school_summary['residual'], school_summary['Google_rating'], color='black', s=2)
